# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\\Users\\ismail_elmain\\Downloads\\Cockpit\\bda_revenu_billing_mock.csv", sep=';')

# %%
df.head()
# Out:
#                id_date  id_day  id_week  id_month  id_year segment  split  \
# 0  2026-01-01 00:00:00       1        1         1     2026     B2B   OTEO
# 1  2026-01-01 00:00:00       1        1         1     2026     B2C   FTTH
# 2  2026-01-01 00:00:00       1        1         1     2026     B2C    WIN
# 3  2026-01-01 00:00:00       1        1         1     2026     B2C   IDAR
# 4  2024-04-01 00:00:00       1       14         4     2024     B2C  FLEXI
#
#     valeur_d1             kpi
# 0   275641772  REVENU BILLING
# 1   931647923  REVENU BILLING
# 2   432376968  REVENU BILLING
# 3  1968208301  REVENU BILLING
# 4    34290627  REVENU BILLING

# %%
df['segment'].unique().tolist()
# Out:
# ['B2B', 'B2C']

# %%
df['split'].unique().tolist()
# Out:
# ['OTEO',
#  'FTTH',
#  'WIN',
#  'IDAR',
#  'FLEXI',
#  'ADSL',
#  'B2C MOBILE',
#  'WHOLESALE',
#  'B2B',
#  'IDAR 5G']

# %%
df['kpi'].unique().tolist()
# Out:
# ['REVENU BILLING']
